# %% [markdown]
# # Example notebook usage of DESI tile picker

# %%
import tilepicker
from astropy.io import fits

tiles = fits.getdata('tiles.fits')

# %%
tilepicker.plot_visibility(tiles, airmass=1.5)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1018">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0db8df4e-2549-4632-85be-4de6f4053808"></div>
